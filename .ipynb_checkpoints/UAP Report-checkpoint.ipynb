# %% [markdown]
# # UAP Report
#
# Brock authored journal publications as OA and not-OA
#
# Providence
# - OpenAlex ROR as identifer
# - OpenAlex OA as identifer
# - Arranged by academic year (July 30 - June 1)

# %%
import pandas as pd
import plotly.express as px
from IPython.display import FileLink

# %%
upa_df = pd.read_csv("uap_report.csv")
fig = px.bar(upa_df, x="Year", y =["Closed Publications", "Open Access Publications"],barmode="stack")
fig.show()


print("Download data: ")
FileLink("uap_report.csv")`
